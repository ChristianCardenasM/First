# %% [markdown]
# ## Github

# %%
#@title git
"""
# %pwd                              # get the current working directory
# %ls                               # list of files and directories
# %cd /content/First                # change current working directorie
# !git rev-parse --show-toplevel    # current working directory

# !touch file1.txt                      # create a file
# !mv file1.txt file2.txt               # change file's name
# !cp file2.txt file3.txt               # make copy of a file
# !rm file3.txt                         # remove file

# !cp /content/drive/MyDrive/meanings.ipynb /content/First/abc.ipynb

# !mkdir xyz                 # make directory
# !mv xyz xyz1               # rename directory
# !cp -r xyz1 xyz2           # copy directory
# !rm -r xyz1                # remove directory
"""

# %%
#@title os

import os
import shutil

"""
os.getcwd()
os.listdir()
os.chdir('/content/First')
os.getcwd()

open('file1.txt', 'w').close()
os.rename('file1.txt', 'file2.txt')
shutil.copy('file2.txt', 'file3.txt')
os.remove('file3.txt')

os.mkdir('directory')
os.rename('directory', 'directory1')
shutil.copytree('directory1', 'directory2')
shutil.rmtree('directory1')
"""
# Out:
# '/content/First'

# %%
#@title MANAGING

#1 CLONE
# !git clone https://github.com/ChristianCardenasM/First
# %cd First

# CONFIG GITHUB USER
# !git config --global user.email "christian.cardenas.spc@gmail.com"
# !git config --global user.name "ChristianCardenasM"

# ADD COOMENT
# !git add .
# !git commit -m "save changes"

# SAVE CHANGES
# !git push https://<github_username>:<github_key>@github.com/<github_username>/<repositorie_name>
# Out:
# Cloning into 'First'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 3), reused 9 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 338.16 KiB | 26.01 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %% [markdown]
# <font size=4><b>Applying</b></font>

# %%
cp /content/drive/MyDrive/meanings.xlsx /content/First/meanings.xlsx
